# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Peugeot207.csv')

df
# Out:
#     code    brand  km  model  year   color    gearbox    option  price
# 0      0  Peugeot   0    207  1399    Grey     Manual   Typical    310
# 1      1  Peugeot   0    207  1400   White     Manual   Typical    320
# 2      2  Peugeot   0    207  1400   Black     Manual   Typical    340
# 3      3  Peugeot   0    207  1400   White     Manual   Typical    325
# 4      4  Peugeot   0    207  1400   White     Manual   Typical    320
# 5      5  Peugeot   0    207  1398   Black  Automatic   Typical    378
# 6      6  Peugeot   0    207  1400  Silver  Automatic  Panaroma    420
# 7      7  Peugeot   0    207  1399    Grey  Automatic  Panaroma    430
# 8      8  Peugeot   0    207  1399   White     Manual  Panaroma    400
# 9      9  Peugeot   0    207  1400   White  Automatic  Panaroma    425
# 10    10  Peugeot   0    207  1400   Black  Automatic  Panaroma    425
# 11    11  Peugeot   0    207  1400    Grey  Automatic   Typical    408
# ...

# %%
colors=pd.get_dummies(df['color'])

colors
# Out:
#     Black  Grey  Silver  White
# 0       0     1       0      0
# 1       0     0       0      1
# 2       1     0       0      0
# 3       0     0       0      1
# 4       0     0       0      1
# 5       1     0       0      0
# 6       0     0       1      0
# 7       0     1       0      0
# 8       0     0       0      1
# 9       0     0       0      1
# 10      1     0       0      0
# 11      0     1       0      0
# 12      1     0       0      0
# 13      0     1       0      0
# 14      0     0       0      1

# %%
df_new=pd.concat([df,colors],axis=1)

df_new
# Out:
#     code    brand  km  model  year   color    gearbox    option  price  Black  \
# 0      0  Peugeot   0    207  1399    Grey     Manual   Typical    310      0
# 1      1  Peugeot   0    207  1400   White     Manual   Typical    320      0
# 2      2  Peugeot   0    207  1400   Black     Manual   Typical    340      1
# 3      3  Peugeot   0    207  1400   White     Manual   Typical    325      0
# 4      4  Peugeot   0    207  1400   White     Manual   Typical    320      0
# 5      5  Peugeot   0    207  1398   Black  Automatic   Typical    378      1
# 6      6  Peugeot   0    207  1400  Silver  Automatic  Panaroma    420      0
# 7      7  Peugeot   0    207  1399    Grey  Automatic  Panaroma    430      0
# 8      8  Peugeot   0    207  1399   White     Manual  Panaroma    400      0
# 9      9  Peugeot   0    207  1400   White  Automatic  Panaroma    425      0
# 10    10  Peugeot   0    207  1400   Black  Automatic  Panaroma    425      1
# ...
