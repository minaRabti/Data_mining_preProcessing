# %%
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt

# %%
df=pd.read_excel('heartP.xlsx')

df
# Out:
#      Unnamed: 0  age  sex  cp   bp  chol  fbs  elc   hr exercise  dep  slop  \
# 0             0   63    1   1  145   233    1    2  150        0  2.3     0
# 1             1   67    1   2  160   286    0    2  108        1  1.5     2
# 2             2   67    1   2  120   229    0    2  129        1  2.6     2
# 3             3   37    1   3  130   250    0    1  187        0  3.5     0
# 4             4   41    0   0  130   204    0    2  172        0  1.4     1
# ..          ...  ...  ...  ..  ...   ...  ...  ...  ...      ...  ...   ...
# 298         298   45    1   1  110   264    0    1  132        0  1.2     2
# 299         299   68    1   2  144   193    1    1  141        0  3.4     2
# 300         300   57    1   2  130   131    0    1  115        1  1.2     2
# 301         301   57    0   0  130   236    0    2  174        0  0.0     2
# 302         302   38    1   3  138   175    0    1  173        0  0.0     1
#
#           num  thal  y
# 0    0.000000     0  0
# ...

# %%
plt.hist(df['age'],edgecolor='black')
plt.xlabel('age')
plt.show()

# %%
df['age'].plot(kind='kde')
plt.show()

# %%
plt.hist(df['chol'],edgecolor='black')
plt.xlabel('chol')
plt.show()

# %%
df['age'].describe()
# Out:
# count    303.000000
# mean      54.438944
# std        9.038662
# min       29.000000
# 25%       48.000000
# 50%       56.000000
# 75%       61.000000
# max       77.000000
# Name: age, dtype: float64

# %%
th_low = 54.43-3*9.038
th_high = 54.43 + 3*9.038

print(th_low)

print(th_high)
# Out:
# 27.316
# 81.544

# %%
df['chol'].describe()
# Out:
# count    303.000000
# mean     246.693069
# std       51.776918
# min      126.000000
# 25%      211.000000
# 50%      241.000000
# 75%      275.000000
# max      564.000000
# Name: chol, dtype: float64

# %%
246.69-3*51.776
# Out:
# 91.362

# %%
246.69+3*51.776
# Out:
# 402.01800000000003

# %%
(92,402)

# %%
plt.boxplot(df['chol'])

plt.show()

# %%
df.plot(kind='box',figsize=(14,14),subplots=True,layout=(4,4))

plt.show()

# %%
df.hist(figsize=(14,14),layout=(4,4))

plt.show()

# %%
df.describe()
# Out:
#               age         sex          cp          bp        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.438944    0.679868    1.877888  131.689769  246.693069    0.148515
# std      9.038662    0.467299    1.004101   17.599748   51.776918    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     48.000000    0.000000    2.000000  120.000000  211.000000    0.000000
# 50%     56.000000    1.000000    2.000000  130.000000  241.000000    0.000000
# 75%     61.000000    1.000000    3.000000  140.000000  275.000000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#               elc          hr    exercise         dep        slop         num  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     1.475248  149.607261    0.326733    1.039604    1.392739    0.663366
# ...

# %%
df['chol'].mean(axis=0)
# Out:
# 246.69306930693068

# %%
df['chol'].std(axis=0)
# Out:
# 51.776917542637015

# %%
df['chol'].var(axis=0)
# Out:
# 2680.8491902170326

# %%
df.head()
# Out:
#    Unnamed: 0  age  sex  cp   bp  chol  fbs  elc   hr exercise  dep  slop  \
# 0           0   63    1   1  145   233    1    2  150        0  2.3     0
# 1           1   67    1   2  160   286    0    2  108        1  1.5     2
# 2           2   67    1   2  120   229    0    2  129        1  2.6     2
# 3           3   37    1   3  130   250    0    1  187        0  3.5     0
# 4           4   41    0   0  130   204    0    2  172        0  1.4     1
#
#    num  thal  y
# 0  0.0     0  0
# 1  3.0     1  1
# 2  2.0     2  1
# 3  0.0     1  0
# 4  0.0     1  0

# %%
del df['Unnamed: 0']

# %%
df=df.replace(['بلله'],'1')

# %%
from sklearn.neighbors import LocalOutlierFactor

lof = LocalOutlierFactor(n_neighbors=30)

yout=lof.fit_predict(df)

# %%
lof.negative_outlier_factor_
# Out:
# array([-1.01737859, -1.12093162, -1.03995886, -1.10413523, -0.9922985 ,
#        -0.99292118, -0.99318228, -1.29381352, -0.98231742, -0.98460919,
#        -0.9910497 , -0.98993865, -0.97762101, -1.0334869 , -1.28621154,
#        -1.29212252, -0.99698691, -0.97081393, -1.01231894, -1.00138115,
#        -1.01288347, -1.03518005, -1.0107768 , -0.96728247, -1.00368703,
#        -0.97185152, -1.15992962, -1.13034935, -1.02713849, -1.29870785,
#        -1.00108881, -0.97971726, -1.07058188, -0.9646424 , -0.99365927,
#        -0.99575202, -1.13276483, -1.10369488, -1.22675671, -1.06253712,
#        -1.12731574, -1.057843  , -1.0698657 , -1.02720642, -1.0529314 ,
#        -0.98826822, -1.15850236, -1.13151722, -2.18077626, -0.98278442,
#        -1.08587398, -1.09868931, -1.04300344, -1.04492099, -0.9793324 ,
#        -1.13078981, -0.98178009, -1.16813573, -0.98949917, -1.03275574,
#        -0.99061565, -1.07569758, -1.01652805, -1.00598256, -1.08311247,
# ...

# %%
len(yout)
# Out:
# 303

# %%
#clean local outlier

dfOUT=df.assign(outlier=yout)

# %%
dfOUT[dfOUT['outlier']==-1]
# Out:
#      age  sex  cp   bp  chol  fbs  elc   hr exercise  dep  slop  num  thal  y  \
# 48    65    0   3  140   417    1    2  157        0  0.8     1  1.0     1  0
# 93    44    0   3  108   141    0    1  175        0  0.6     2  0.0     1  0
# 121   63    0   2  150   407    0    2  154        0  4.0     2  3.0     2  1
# 152   67    0   3  115   564    0    2  160        0  1.6     2  0.0     2  0
# 173   62    0   2  140   394    0    2  157        0  1.2     2  0.0     1  0
# 181   56    0   2  134   409    0    2  150        1  1.9     2  2.0     2  1
# 188   54    1   0  192   283    0    2  195        0  0.0     1  1.0     2  1
# 202   57    1   3  150   126    1    1  173        0  0.2     1  1.0     2  0
# 245   67    1   2  120   237    0    1   71        0  1.0     2  0.0     1  1
# 296   59    1   2  164   176    1    2   90        0  1.0     2  2.0     0  1
# 300   57    1   2  130   131    0    1  115        1  1.2     2  1.0     2  1
#
#      outlier
# 48        -1
# ...

# %%
dfClean=dfOUT[dfOUT['outlier']==1]

# %%
dfClean
# Out:
#      age  sex  cp   bp  chol  fbs  elc   hr exercise  dep  slop       num  \
# 0     63    1   1  145   233    1    2  150        0  2.3     0  0.000000
# 1     67    1   2  160   286    0    2  108        1  1.5     2  3.000000
# 2     67    1   2  120   229    0    2  129        1  2.6     2  2.000000
# 3     37    1   3  130   250    0    1  187        0  3.5     0  0.000000
# 4     41    0   0  130   204    0    2  172        0  1.4     1  0.000000
# ..   ...  ...  ..  ...   ...  ...  ...  ...      ...  ...   ...       ...
# 297   57    0   2  140   241    0    1  123        1  0.2     2  0.000000
# 298   45    1   1  110   264    0    1  132        0  1.2     2  0.000000
# 299   68    1   2  144   193    1    1  141        0  3.4     2  2.000000
# 301   57    0   0  130   236    0    2  174        0  0.0     2  1.000000
# 302   38    1   3  138   175    0    1  173        0  0.0     1  0.672241
#
#      thal  y  outlier
# 0       0  0        1
# 1       1  1        1
# ...

# %%
df.shape
# Out:
# (303, 14)

# %%
df_=df.drop_duplicates()

# %%
df_.shape
# Out:
# (303, 14)

# %%
df.iloc

# %%
df['age']
# Out:
# 0      63
# 1      67
# 2      67
# 3      37
# 4      41
#        ..
# 298    45
# 299    68
# 300    57
# 301    57
# 302    38
# Name: age, Length: 303, dtype: int64

# %%
year_age=1402 - df['age']

# %%
df['yearAge']=year_age

# %%
df
# Out:
#      age  sex  cp   bp  chol  fbs  elc   hr exercise  dep  slop       num  \
# 0     63    1   1  145   233    1    2  150        0  2.3     0  0.000000
# 1     67    1   2  160   286    0    2  108        1  1.5     2  3.000000
# 2     67    1   2  120   229    0    2  129        1  2.6     2  2.000000
# 3     37    1   3  130   250    0    1  187        0  3.5     0  0.000000
# 4     41    0   0  130   204    0    2  172        0  1.4     1  0.000000
# ..   ...  ...  ..  ...   ...  ...  ...  ...      ...  ...   ...       ...
# 298   45    1   1  110   264    0    1  132        0  1.2     2  0.000000
# 299   68    1   2  144   193    1    1  141        0  3.4     2  2.000000
# 300   57    1   2  130   131    0    1  115        1  1.2     2  1.000000
# 301   57    0   0  130   236    0    2  174        0  0.0     2  1.000000
# 302   38    1   3  138   175    0    1  173        0  0.0     1  0.672241
#
#      thal  y  yearAge
# 0       0  0     1339
# 1       1  1     1335
# ...
